# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
import numpy as np

# %%
# YOU MUST PUT sheet_name=None TO READ ALL CSV FILES IN YOUR XLSM FILE
df = pd.read_excel ('Datasets/Flat.File.PetSupplies_b2b.xlsm' , sheet_name=None) #place "r" before the path string to address special character, such as '\'. Don't forget to put the file name at the end of the path + '.xlsx'

# %%
print (df)
# Out:
# OrderedDict([('icons', Empty DataFrame
# Columns: []
# Index: []), ('International URLs',      Unnamed: 0                                         Unnamed: 1
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# 5           NaN                                                NaN
# 6           NaN                                                NaN
# 7           NaN                                                NaN
# 8           NaN                                                NaN
# 9           NaN                                                NaN
# 10     Language                                        Contact URL
# 11  English USA  https://merchant-query.amazon.com/query/?Servi...
# ...

# %%
# prints all sheets name in an ordered dictionary
print(df.keys())
# Out:
# odict_keys(['icons', 'International URLs', 'International Settings', 'DropdownSizer', 'Instructions', 'Images', 'International Translations', 'Data Validation', 'International Data', 'Example', 'Data Definitions', 'Template', 'Valid Values', 'Dropdown Lists', 'AttributePTDMAP'])

# %%
# prints sheet name or any sheet if you know it's index
sheet_name = list(df.keys())[11]
print(sheet_name)
# Out:
# Template

# %%
df[sheet_name]
# Out:
#     TemplateType=fptcustom Version=2020.0112 Category=petsupplies  \
# 0             Product Type        Seller SKU           Brand Name
# 1        feed_product_type          item_sku           brand_name
# 2          petsuppliesmisc          FPS-0001              generic
# 3          petsuppliesmisc          FPS-0002              generic
# 4          petsuppliesmisc          FPS-0003              generic
# 5          petsuppliesmisc          FPS-0004              generic
# 6          petsuppliesmisc          FPS-0005              generic
# 7          petsuppliesmisc          FPS-0006              generic
# 8          petsuppliesmisc          FPS-0007              generic
# 9          petsuppliesmisc          FPS-0008              generic
# 10         petsuppliesmisc          FPS-0009              generic
# 11         petsuppliesmisc          FPS-0010              generic
# 12         petsuppliesmisc          FPS-0011              generic
# ...

# %%
# prints sheet or any sheet if know it's name
# print(df[sheet_name])

# %%
df[sheet_name].columns
# Out:
# Index(['TemplateType=fptcustom', 'Version=2020.0112', 'Category=petsupplies',
#        'TemplateSignature=UEVUX0ZPT0QsUEVUX0ZVUl9ERU9ET1JJWkVSLFBFVF9TVVBQTElFUyxQRVRfSEVBTFRIX0NBUkUsUEVUX1BFU1RfQ09OVFJPTCxBTklNQUxfQ09MTEFSLFBFVF9BUFBBUkVM',
#        'The top 3 rows are for Amazon.com use only. Do not modify or delete the top 3 rows.',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 266', 'Unnamed: 267', 'Unnamed: 268', 'Unnamed: 269',
#        'Unnamed: 270', 'Unnamed: 271', 'Unnamed: 272', 'Unnamed: 273',
#        'Unnamed: 274', 'Unnamed: 275'],
#       dtype='object', length=276)

# %%
df[sheet_name]["Unnamed: 8"]
# Out:
# 0          Your price
# 1      standard_price
# 2               27.99
# 3               38.00
# 4               19.95
# 5                9.99
# 6               32.99
# 7               20.00
# 8               20.00
# 9               35.99
# 10              25.00
# 11              22.00
# 12              20.00
# 13              20.00
# 14              21.99
# 15               7.00
# 16              26.99
# 17              35.99
# 18              20.99
# 19              20.00
# 20              11.99
# 21              32.00
# 22              26.99
# 23               7.00
# 24              23.99
# 25              12.99
# 26              25.99
# 27              10.00
# 28              24.99
# 29              11.99
#             ...
# 473               NaN
# 474               NaN
# 475               NaN
# 476               NaN
# 477               NaN
# 478               NaN
# 479               NaN
# 480               NaN
# 481               NaN
# 482               NaN
# ...

# %%
# newprice = df[sheet_name]["Unnamed: 25"]
df[sheet_name]["Unnamed: 8"] = pd.to_numeric(df[sheet_name]["Unnamed: 8"],errors='coerce')
new_price = df[sheet_name]["Unnamed: 8"] + 7.5
new_price
# Out:
# 0        NaN
# 1        NaN
# 2      35.49
# 3      45.50
# 4      27.45
# 5      17.49
# 6      40.49
# 7      27.50
# 8      27.50
# 9      43.49
# 10     32.50
# 11     29.50
# 12     27.50
# 13     27.50
# 14     29.49
# 15     14.50
# 16     34.49
# 17     43.49
# 18     28.49
# 19     27.50
# 20     19.49
# 21     39.50
# 22     34.49
# 23     14.50
# 24     31.49
# 25     20.49
# 26     33.49
# 27     17.50
# 28     32.49
# 29     19.49
#        ...
# 473      NaN
# 474      NaN
# 475      NaN
# 476      NaN
# 477      NaN
# 478      NaN
# 479      NaN
# 480      NaN
# 481      NaN
# 482      NaN
# 483      NaN
# 484      NaN
# 485      NaN
# 486      NaN
# 487      NaN
# 488      NaN
# 489      NaN
# 490      NaN
# 491      NaN
# 492      NaN
# 493      NaN
# 494      NaN
# 495      NaN
# 496      NaN
# 497      NaN
# 498      NaN
# 499      NaN
# 500      NaN
# 501      NaN
# 502      NaN
# Name: Unnamed: 8, Length: 503, dtype: float64

# %%
df = new_price

# %%
# export first sheet to file
df.to_csv('Datasets/New_pet_price.csv')
