# %%
import mysql.connector

# %%
import pandas as pd

# %%
db = mysql.connector.connect(
    db="schohxlg_scholarx",
   host="localhost",
   user="demolablaze",
   passwd="$Omerta2019"
)

# %%
print(db)

# %%
df = pd.read_sql_query("SELECT * FROM scholarships",db)

# %%
df.tail(10)
# Out:
#           id          created_at          updated_at  \
# 16124  64472 2019-03-18 16:30:18 2019-07-22 08:45:27
# 16125  64473 2019-03-18 16:30:18 2019-07-22 08:45:27
# 16126  64474 2019-03-18 16:30:18 2019-07-22 08:45:27
# 16127  64475 2019-03-18 16:30:18 2019-07-22 08:45:27
# 16128  64476 2019-03-18 16:30:18 2019-07-22 08:45:27
# 16129  64477 2019-03-18 16:30:18 2019-06-23 17:30:55
# 16130  64478 2019-03-18 16:30:18 2019-05-06 00:40:15
# 16131  64479 2019-03-18 16:30:18 2019-05-06 00:40:15
# 16132  64480 2019-03-18 16:30:18 2019-05-06 00:40:15
# 16133  64481 2019-03-18 16:30:18 2019-05-06 00:40:15
#
#                                          name  \
# 16124  Total International Scholarship - 2019
# 16125  Total International Scholarship - 2019
# 16126  Total International Scholarship - 2019
# 16127  Total International Scholarship - 2019
# 16128  Total International Scholarship - 2019
# 16129  Total International Scholarship - 2019
# 16130  Total International Scholarship - 2019
# ...
