# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('Datasets/films.csv')

# %%
df
# Out:
#        adult    budget                                             genres  \
# 0      FALSE  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      FALSE  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      FALSE         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      FALSE  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4      FALSE         0                     [{'id': 35, 'name': 'Comedy'}]
# 5      FALSE  60000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 6      FALSE  58000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 7      FALSE         0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 8      FALSE  35000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 9      FALSE  58000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 10     FALSE  62000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 11     FALSE         0  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# ...

# %%
df.head()
# Out:
#    adult    budget                                             genres  \
# 0  FALSE  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  FALSE  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  FALSE         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  FALSE  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4  FALSE         0                     [{'id': 35, 'name': 'Comedy'}]
#
#   popularity                               production_companies  \
# 0  21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2    11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3   3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4   8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# ...

# %%
import matplotlib.pyplot as plt

# %%
data = df[0:10][["revenue", "vote_average"]]
data
# Out:
#        revenue  vote_average
# 0  373554033.0           7.7
# 1  262797249.0           6.9
# 2          0.0           6.5
# 3   81452156.0           6.1
# 4   76578911.0           5.7
# 5  187436818.0           7.7
# 6          0.0           6.2
# 7          0.0           5.4
# 8   64350171.0           5.5
# 9  352194034.0           6.6

# %%
revenue = data.revenue
vote_average = data.vote_average

# %%
plt.xlabel("revenue")
plt.ylabel("vote_average")

#
plt.plot(vote_average, revenue)

# %%
plt.bar(vote_average, revenue)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar(data["vote_average"], data["revenue"]/1000000, width =0.2, color =["red", "blue"])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.ylabel("Revenue(In Millions)")
plt.xlabel("Vote average")
plt.title("Movie Revenue - Votes")
plt.bar(data["vote_average"], data["revenue"]/1000000, width =0.1, color =["green"])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.ylabel("Revenue(In Millions)")
plt.xlabel("Vote average")
plt.title("Movie Revenue - Votes")
plt.barh(data["vote_average"], data["revenue"]/1000000,color =["green"])
# Out:
# <BarContainer object of 10 artists>
