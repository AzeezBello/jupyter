# %%
#This will not run on online IDE 
import requests 
from bs4 import BeautifulSoup 
  
URL = "https://www.jumia.com.ng/mens-shoes/"
r = requests.get(URL) 
  
soup = BeautifulSoup(r.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Buy Men's Shoes | Brogues, Oxfords, Casual Shoes | Jumia
#   </title>
#   <meta content="product" property="og:type"/>
#   <meta content="Jumia Nigeria" property="og:site_name"/>
#   <meta content="Buy Men's Shoes | Brogues, Oxfords, Casual Shoes | Jumia " property="og:title"/>
#   <meta content="Find the best prices on men's shoes online at Jumia Nigeria. Shop a large selection of Loafers, Formal Shoes, Boots, Sneakers &amp; more - top brands - Zara, David Wej &amp; more - Order Now!" property="og:description"/>
#   <meta content="/mens-shoes/" property="og:url"/>
#   <meta content="https://ng.jumia.is/cms/jumialogonew.png" property="og:image"/>
#   <meta content="en_NG" property="og:locale"/>
#   <meta content="Buy Men's Shoes | Brogues, Oxfords, Casual Shoes | Jumia " name="title"/>
#   <meta content="index,follow" name="robots"/>
# ...

# %%
#Python program to scrape website  
#and save quotes from website 
import requests 
from bs4 import BeautifulSoup 
import csv 
   
URL = "https://www.jumia.com.ng/mens-shoes/"
r = requests.get(URL) 
   
soup = BeautifulSoup(r.content, 'html5lib') 
   
products=[]  # a list to store products 
   
table = soup.find('div', attrs = {'class':'paxs row _no-g _4cl-3cm-shs'})  
   
for row in table.findAll('article', 
                         attrs = {'class':'prd _fb col c-prd'}): 
    product = {} 
    product['name'] = a.div.h3.text 
    product['img'] = a.div.img['src'] 

    products.append(product) 
   
filename = 'Jumia_products.csv'
with open(filename, 'w', newline='') as f: 
    w = csv.DictWriter(f,['name','img',]) 
    w.writeheader() 
    for quote in quotes: 
        w.writerow(quote)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-dcd25b08b0bf> in <module>
#      14 table = soup.find('div', attrs = {'class':'paxs row _no-g _4cl-3cm-shs'})
#      15
# ---> 16 for row in table.findAll('article',
#      17                          attrs = {'class':'prd _fb col c-prd'}):
#      18     product = {}
#
# AttributeError: 'NoneType' object has no attribute 'findAll'

# %%
# from bs4 import BeautifulSoup as soup
# from urllib.request import urlopen as ureq
# import urllib.request

# %%
from bs4 import BeautifulSoup 
import requests
import csv

# %%
soup = BeautifulSoup(r.content, 'html5lib')

# %%
user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'
headers={'User-Agent':user_agent,} 
url = "https://www.walmart.com/search/?max_price=1500&min_price=150&page=1&query=Home+office+desk&value=%24150+-+%241500"

request=urllib.request.Request(url,None,headers) #The assembled request
response = ureq(request)

data = response.read() # The data u need
fullhtml = soup(data, 'html.parser')
response.close()
body = fullhtml.body

# %%
product_cards = body.findAll("li", {"class": ["Grid-col ", "u-size-6-12 u-size-1-4-m u-size-1-5-xl"]}) 
print(product_cards)
# product_cards
# for product in product_cards:
#     print(product_cards.index(product)+1,". ",product.find("span", {"class":"name"}).text)
# Out:
# []
